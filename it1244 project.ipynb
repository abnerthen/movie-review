# %%
import os 
import pandas as pd
import numpy as np

# Folder path
path1 = 'C:/Users/user/Documents/Movie Review/data/pos'

# Change the directory
os.chdir(path1)

def read_text_file(file_path):
    with open(file_path, 'r', encoding='UTF-8') as f:
        return f.read()

data_pos = []

for file in os.listdir():
    if file.endswith('.txt'):
        file_path = f"{path1}/{file}"
        # print(file_path)
        data_pos.append([read_text_file(file_path), 'pos'])

df = pd.DataFrame(data_pos)
# Out:
# C:/Users/user/Documents/Movie Review/data/pos/10000_8.txt
# C:/Users/user/Documents/Movie Review/data/pos/10001_7.txt
# C:/Users/user/Documents/Movie Review/data/pos/10002_8.txt
# C:/Users/user/Documents/Movie Review/data/pos/10003_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/10004_9.txt
# C:/Users/user/Documents/Movie Review/data/pos/10005_9.txt
# C:/Users/user/Documents/Movie Review/data/pos/10006_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/10007_9.txt
# C:/Users/user/Documents/Movie Review/data/pos/10008_7.txt
# C:/Users/user/Documents/Movie Review/data/pos/10009_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/1000_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/10010_7.txt
# C:/Users/user/Documents/Movie Review/data/pos/10011_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/10012_10.txt
# C:/Users/user/Documents/Movie Review/data/pos/10013_8.txt
# C:/Users/user/Documents/Movie Review/data/pos/10014_8.txt
# ...

# %%
os.chdir('../neg')

print(os.getcwd())

data_neg = []

for file in os.listdir():
    if file.endswith('.txt'):
        file_path = f"{os.getcwd()}/{file}"
        # print(file_path)
        data_neg.append([read_text_file(file_path), 'pos'])

df2 = pd.DataFrame(data_neg)
# Out:
# C:\Users\user\Documents\Movie Review\data\neg
